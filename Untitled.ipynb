# %%
# %load_ext autoreload
# %autoreload 2

from src.trips import query_trips

# %%
gp_trips = [
    '85e76426-5029-431a-8798-cd869500fcf2',
    '1ccf3cbe-0db0-4229-bab1-8e42b37a0411',
    'e9efaba7-a322-4793-a019-9592fb3ee73f'
]

# %%
data = query_trips(gp_trips)
data
# Out:
# Connecting to database
# database connection is closed
#
# Connecting to database
# database connection is closed
#
# Connecting to database
# database connection is closed
# {5056416: [{'way_id': 5056416, 'way_dist': 29.563, 'value': 2.2657819005},
#   {'way_id': 5056416, 'way_dist': 38.998, 'value': 2.484675576},
#   {'way_id': 5056416, 'way_dist': 46.36, 'value': 1.9722537475},
#   {'way_id': 5056416, 'way_dist': 48.433, 'value': 1.046971414},
#   {'way_id': 5056416, 'way_dist': 55.51, 'value': 0.984022071},
#   {'way_id': 5056416, 'way_dist': 58.497, 'value': 1.2915081515},
#   {'way_id': 5056416, 'way_dist': 63.022999999999996, 'value': 3.618177712},
#   {'way_id': 5056416, 'way_dist': 64.66, 'value': 2.4879218610000002},
#   {'way_id': 5056416, 'way_dist': 67.932, 'value': 4.0767673635},
#   {'way_id': 5056416, 'way_dist': 72.447, 'value': 1.8644350315},
#   {'way_id': 5056416, 'way_dist': 73.81, 'value': 3.255174561},
# ...
